# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### Data vizulization

# %%
# Data visualization is the visual representation of information and data. 
# It uses visual elements like charts, graphs, and maps to communicate complex data relationships and insights in a way that is easy to understand. 
# It helps to identify trends, outliers, and patterns in data that might be missed in raw data form, making it easier to extract actionable insights

# %% [markdown]
# ### Introduction to matplotlib

# %%
# Graphs that matplotlib provide
# 1. Line Graph   - compare Trend
# 2. Bar Chart    - compare Different Group
# 3. Pie Chart    - To show parts of whole 
# 4. Histogram    - To show Frequency and Distribution 
# 5. Scatter Plot - To find relation between Two points 
# Also we customization on these Graphs

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4] 
y = [10,20,15,25]

plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Terms you should know

# %% [markdown]
# 1. Data point
# 2. x-axis / y-axis
# 3. Figure
# 4. Axes
# 5. Plot
# 6. Marker
# 7. Line
# 8. Line Style
# 9. color
# 10. Legend
# 11. Label
# 12. Title
# 13. Grid
# 14. Function
# 15. Method
# 16. Parameters
# 17. Keyword Arguments
# 18. Object-Oriented API
# 19. DPL (Dots per inch)
# 20. Backend

# %% [markdown]
# ### Understanding Pyplot

# %%
import matplotlib.pyplot as plt 

x = ['Mon', 'Tues', 'Wed', 'Thur', 'Fri']  #x-axis
y = [10,15,7,20,12]  #y-axis

plt.plot(x,y)

plt.title('Bakery Sale This Week!')
plt.xlabel('Day of the week')
plt.ylabel('Sale per Day')

plt.show()

# %% [markdown]
# pyplot : for small projects (Beginners level)
#
# object oriented API : for big project (Advance level)

# %% [markdown]
# ### pyplot Functions

# %% [markdown]
# ##### 1. plt.plot()
# ##### 2. plt.xlabel()
# ##### 3. plt.ylabel()
# ##### 4. plt.title()
# ##### 5. plt.legend()
# ##### 6. plt.grid()
# ##### 7. plt.xlim()
# ##### 8. plt.ylim()
# ##### 9. plt.xticks()
# ##### 10. plt.yticks()
# ##### 11. plt.show()

# %%
# plt.plot(x,y, color='color name', linestyle='line_style', linewidth=value, marker='marker symbol', label='label name')
# plt.xlabel('text') and plt.ylabel('text')

import matplotlib.pyplot as plt

months = [1,2,3,4]
sales = [1000, 1500, 1200, 1800]

plt.plot(months, sales, color='blue', linestyle='--', linewidth=2, marker='o', label='2025 sales data')
plt.xlabel('Months')
plt.ylabel('Sales per month')
plt.title('Monthly Sales Data Report')
plt.legend(loc='upper left')   # loc='bottom right'
plt.grid(color='gray', linestyle=':', linewidth=1)
plt.xlim(1,4)
plt.ylim(0,2000)
plt.xticks([1,2,3,4],['M1', 'M2', 'M3', 'M4'])

plt.show()

# %% [markdown]
# ### Plotting Bar Charts, Pie Charts, Histograms, Vector Graphs

# %% [markdown]
# #### Bar chart = category comparison Data Analysis

# %%
# plt.bar(x, height, color='color name', width='value', label='label name')

import matplotlib.pyplot as plt

product = ['A', 'B', 'C', 'D']
sales = [1000,1500,800,1200]

# plt.bar() --> vertical
# plt.barh() --> Horizontal
plt.bar(product, sales, color='orange', label='Sales 2025')    

plt.xlabel('Product')
plt.ylabel('Sales')
plt.title('Product sale comparison')
plt.legend()

plt.show()

# %% [markdown]
# #### Pie Chart = Proportion illustration Whole Representation

# %%
# plt.pie(values, labels=label_list, colors=color_list, autopct='%1.1f%%')

import matplotlib.pyplot as plt

regions = ['North', 'South', 'East', 'West']
revenue = [3000,2000,1500,1000]

plt.pie(revenue, labels=regions, autopct='%1.1f%%', colors=['gold', 'skyblue', 'lightgreen', 'coral'])
plt.title('Revenue Contribution By Region')

plt.show()

# %% [markdown]
# #### Histograms = Numerical Distribution Data Insights

# %%
# plt.hist(data, bins=number_of_bins, color='colorname', edgecolor='black')
# Hieght of bar = Number of students in that range

import matplotlib.pyplot as plt

scores = [45,67,89,56,78,88,92,60,74,81,59,66,75,82,90,85,70,73,68,77]

plt.hist(scores, bins=5, color='purple', edgecolor='black')  # bins refers to 5 different ranges 

plt.xlabel('Score Range')
plt.ylabel('Number of Students')
plt.title('Score Distribution of Students')

plt.show()

# %% [markdown]
# # Scatter plot

# %%
# plt.scatter(x, y, color='color_name', marker='marker style', label='label name')

import matplotlib.pyplot as plt

hours_studies = [1,2,3,4,5,6,7,8]
exam_scores = [50,55,60,65,70,75,80,85]

plt.scatter(hours_studies,exam_scores, color='green', marker='o', label='Student Data')

plt.xlabel('Hourse Studied')
plt.ylabel('Exam Score')
plt.title('Relationship Between Study Time and Exam Score')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Using Two Datasets

import matplotlib.pyplot as plt

plt.scatter([1,2,3],[50,55,60], color='blue', label='Class A')  # Group 1
plt.scatter([1,2,3],[45,50,52], color='orange', label='Class B')  # Group 2

plt.xlabel('Hourse Studied')
plt.ylabel('Exam Score')
plt.title('Comparison of Two Classes')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # Subplot Functions in Matplotlib

# %% [markdown]
# ##### 1. plt.subplot()
# ##### 2. plt.tight_layout()
# ##### 3. fig.suptitle()

# %%
# plt.subplot(nrows, ncols, index)  here index is start with 1.

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

plt.subplot(1,2,1)  # 1 Row, 2 Column, 1st Subplot 
plt.plot(x,y)
plt.title('Line chart')

plt.subplot(1,2,2)  # 1 Row, 2 Column, 2nd Subplot
plt.bar(x,y)
plt.title('Bar chart')

plt.tight_layout()  # Auto adjust both the graphs
plt.show()

# %%
# More preferable --> We have more control over subplots

import matplotlib.pyplot as plt

# fig, ax = plt.subplots(nrows, ncols, figsize=(width,height))
fig, ax = plt.subplots(1,2, figsize=(10,5))

x = [1,2,3,4]
y = [10,20,15,25]

ax[0].plot(x,y, color='blue')
ax[0].set_title('Line Plot')

ax[1].bar(x,y, color='green')
ax[1].set_title('Bar Chart')

fig.suptitle('Comparison of Line and Bar Chart')        # To add a title 

plt.tight_layout()      # Auto-adjust both the graphs 
plt.show()

# %% [markdown]
# # Function: Saving Visulization

# %% [markdown]
# ### savefig()

# %%
# savefig('folder_name(optional)/filename.extension', dpi = value, bbox_inches = 'tight)

# filename.extension = outputfile with extension 
# dip(dots per inch) = Control image resoluation 
# bbox_inches = Fit the graph in the screen

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

# Create a plot
plt.plot(x,y, color='blue', marker='o')
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.savefig('line_plot.png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Netflix Project

# %% [markdown]
# Step name                           What we'll  do
# ---------------------------------------------------------------------------------------------
# Load the data                 -  Read the CSV file using pandas.
# clean the data                -  Handle missing values,remove duplicates,fix columns if need.
# understand the data           -  Use head(),info(),describe() to explore the dataset.
# identify questions to answer  -  What do we want to know? (Eg: Movies vs TV shows,Rating,etc)
# Visulize the data (EDA)       -  Use Matplotlib to draw charts and answer these que visually.
# Save the plots                -  Use plt.savefig() for your reports.

# %%
# import the libraries
import pandas as pd
import matplotlib.pyplot as plt

# load the data 
df = pd.read_csv('netflix_titles.csv')

# clean the data 
df = df.dropna(subset=['type','director','cast','release_year','rating','country','duration'])

# count the null data
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# Question - 1

# %%
# How many Movies vs TV Shows?
# Bar chart --> plt.bar()

type_counts = df['type'].value_counts()
plt.figure(figsize=(6,4))

plt.bar(type_counts.index, type_counts.values, color=['skyblue','orange'])
plt.title('Number of Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# Question - 2

# %%
# What is the percentage of each content rating (PG, R, TV-MA)?
# Pie chart --> plt.pie()

rating_counts = df['rating'].value_counts()
plt.figure(figsize=(8,6))

plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90)

plt.title('percentage of Content Rating')

plt.tight_layout()
plt.show()

# %% [markdown]
# Question - 3

# %%
# How has the number of releases changed over the years?
# Line plot --> plt.plot()

movie_df = df[df['type'] == 'Movie'].copy()
movie_df['duration_int'] = movie_df['duration'].str.replace(' min','').astype(int)

plt.figure(figsize=(8,6))

plt.hist(movie_df['duration_int'], bins=30, color='purple', edgecolor='black')

plt.title('Distribution of Movie Duration')
plt.xlabel('Duration (Minutes)')
plt.ylabel('Number of Movies')

plt.tight_layout()
plt.show()

# %% [markdown]
# Question - 4

# %%
# What is the distribution of movie durations?
# Histogram --> plt.hist()

# %% [markdown]
# Question - 5

# %%
# Relationship between releases year and number of shows?
# Scatter plot --> plt.scatter()  (optional)

release_counts = df['release_year'].value_counts().sort_index()

plt.figure(figsize=(10,6))

plt.scatter(release_counts.index, release_counts.values, color='red')

plt.title('Release Years vs Number of Shows')
plt.xlabel('Release Year')
plt.ylabel('Number of shows')

plt.tight_layout()
plt.show()

# %% [markdown]
# Question - 6

# %%
# Top 10 countries with the highest number of shows?
# Bar chart (Horizontal) --> plt.barh()

country_counts = df['country'].value_counts().head(10)

plt.figure(figsize=(8,6))

plt.barh(country_counts.index, country_counts.values, color='teal')

plt.title('Top 10 Countries by Number of Shows')
plt.xlabel('Number of Shows')
plt.ylabel('Country')

plt.tight_layout()
plt.show()

# %% [markdown]
# Question - 7

# %%
# Compare multiple plots togather(e.g., Movies vs TV Shows by Year)
# Subplots --> plt.subplot() / plt.subplots()  

content_by_year = df.groupby(['release_year','type']).size().unstack().fillna(0)

fig, ax = plt.subplots(1,2, figsize=(12,5)) 

# First Subplot : Movies
ax[0].plot(content_by_year.index, content_by_year['Movie'], color='purple')
ax[0].set_title('Movies Released Per Year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Number of Movies')

# Second Subplot : Movies
ax[0].plot(content_by_year.index, content_by_year['TV Show'], color='orange')
ax[0].set_title('TV Shows Released Per Year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Number of Movies')

fig.suptitle('Comparison of Movies and TV Shows Released Over Years')

plt.tight_layout()
plt.show()

# %% [markdown]
# Question - 8

# %%
# Save final charts
# Saving Figures --> plt.savefig()
 
content_by_year = df.groupby(['release_year','type']).size().unstack().fillna(0)

fig, ax = plt.subplots(1,2, figsize=(12,5)) 

# First Subplot : Movies
ax[0].plot(content_by_year.index, content_by_year['Movie'], color='blue')
ax[0].set_title('Movies Released Per Year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Number of Movies')

# Second Subplot : Movies
ax[0].plot(content_by_year.index, content_by_year['TV Show'], color='orange')
ax[0].set_title('TV Shows Released Per Year')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Number of Movies')

fig.suptitle('Comparison of Movies and TV Shows Released Over Years')

plt.tight_layout()
plt.savefig('Movies_TVShows_Comparison.png')     # To Save the Figure 
plt.show()
